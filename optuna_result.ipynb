# %% [markdown]
# DTC_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTC_beststudy_history.png'><br>
# DTC_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTC_beststudy_metrics.png'><br>
# DTC_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTC_beststudy_score.png'><br>
# DTC_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTC_beststudy_time.png'><br>
# DTC_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTC_overstudy_history.png'><br>
# DTC_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTC_overstudy_metrics.png'><br>
# DTC_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTC_overstudy_score.png'><br>
# DTC_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTC_overstudy_time.png'><br>
# DTR_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTR_beststudy_history.png'><br>
# DTR_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTR_beststudy_metrics.png'><br>
# DTR_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTR_beststudy_score.png'><br>
# DTR_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTR_beststudy_time.png'><br>
# DTR_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTR_overstudy_history.png'><br>
# DTR_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTR_overstudy_metrics.png'><br>
# DTR_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTR_overstudy_score.png'><br>
# DTR_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/DTR_overstudy_time.png'><br>
# ETC_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETC_beststudy_history.png'><br>
# ETC_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETC_beststudy_metrics.png'><br>
# ETC_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETC_beststudy_score.png'><br>
# ETC_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETC_beststudy_time.png'><br>
# ETC_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETC_overstudy_history.png'><br>
# ETC_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETC_overstudy_metrics.png'><br>
# ETC_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETC_overstudy_score.png'><br>
# ETC_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETC_overstudy_time.png'><br>
# ETR_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETR_beststudy_history.png'><br>
# ETR_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETR_beststudy_metrics.png'><br>
# ETR_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETR_beststudy_score.png'><br>
# ETR_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETR_beststudy_time.png'><br>
# ETR_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETR_overstudy_history.png'><br>
# ETR_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETR_overstudy_metrics.png'><br>
# ETR_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETR_overstudy_time.png'><br>
# ETR_overstusy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/ETR_overstusy_score.png'><br>
# GBC_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBC_beststudy_history.png'><br>
# GBC_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBC_beststudy_metrics.png'><br>
# GBC_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBC_beststudy_score.png'><br>
# GBC_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBC_beststudy_time.png'><br>
# GBC_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBC_overstudy_history.png'><br>
# GBC_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBC_overstudy_metrics.png'><br>
# GBC_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBC_overstudy_score.png'><br>
# GBC_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBC_overstudy_time.png'><br>
# GBR_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBR_beststudy_history.png'><br>
# GBR_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBR_beststudy_metrics.png'><br>
# GBR_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBR_beststudy_score.png'><br>
# GBR_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBR_beststudy_time.png'><br>
# GBR_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBR_overstudy_history.png'><br>
# GBR_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBR_overstudy_metrics.png'><br>
# GBR_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBR_overstudy_score.png'><br>
# GBR_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/GBR_overstudy_time.png'><br>
# KNC_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNC_beststudy_history.png'><br>
# KNC_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNC_beststudy_metrics.png'><br>
# KNC_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNC_beststudy_score.png'><br>
# KNC_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNC_beststudy_time.png'><br>
# KNC_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNC_overstudy_history.png'><br>
# KNC_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNC_overstudy_metrics.png'><br>
# KNC_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNC_overstudy_score.png'><br>
# KNC_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNC_overstudy_time.png'><br>
# KNR_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNR_beststudy_history.png'><br>
# KNR_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNR_beststudy_metrics.png'><br>
# KNR_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNR_beststudy_score.png'><br>
# KNR_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNR_beststudy_time.png'><br>
# KNR_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNR_overstudy_history.png'><br>
# KNR_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNR_overstudy_metrics.png'><br>
# KNR_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNR_overstudy_score.png'><br>
# KNR_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/KNR_overstudy_time.png'><br>
# MLPC_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPC_beststudy_history.png'><br>
# MLPC_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPC_beststudy_metrics.png'><br>
# MLPC_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPC_beststudy_score.png'><br>
# MLPC_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPC_beststudy_time.png'><br>
# MLPC_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPC_overstudy_history.png'><br>
# MLPC_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPC_overstudy_metrics.png'><br>
# MLPC_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPC_overstudy_score.png'><br>
# MLPC_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPC_overstudy_time.png'><br>
# MLPR_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPR_beststudy_history.png'><br>
# MLPR_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPR_beststudy_metrics.png'><br>
# MLPR_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPR_beststudy_score.png'><br>
# MLPR_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPR_beststudy_time.png'><br>
# MLPR_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPR_overstudy_history.png'><br>
# MLPR_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPR_overstudy_metrics.png'><br>
# MLPR_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPR_overstudy_score.png'><br>
# MLPR_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/MLPR_overstudy_time.png'><br>
# RFC_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFC_beststudy_history.png'><br>
# RFC_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFC_beststudy_metrics.png'><br>
# RFC_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFC_beststudy_score.png'><br>
# RFC_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFC_beststudy_time.png'><br>
# RFC_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFC_overstudy_history.png'><br>
# RFC_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFC_overstudy_metrics.png'><br>
# RFC_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFC_overstudy_score.png'><br>
# RFC_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFC_overstudy_time.png'><br>
# RFR_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFR_beststudy_history.png'><br>
# RFR_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFR_beststudy_metrics.png'><br>
# RFR_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFR_beststudy_score.png'><br>
# RFR_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFR_beststudy_time.png'><br>
# RFR_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFR_overstudy_history.png'><br>
# RFR_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFR_overstudy_metrics.png'><br>
# RFR_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFR_overstudy_score.png'><br>
# RFR_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/RFR_overstudy_time.png'><br>
# SVC_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVC_beststudy_history.png'><br>
# SVC_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVC_beststudy_metrics.png'><br>
# SVC_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVC_beststudy_score.png'><br>
# SVC_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVC_beststudy_time.png'><br>
# SVC_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVC_overstudy_history.png'><br>
# SVC_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVC_overstudy_metrics.png'><br>
# SVC_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVC_overstudy_score.png'><br>
# SVC_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVC_overstudy_time.png'><br>
# SVR_beststudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVR_beststudy_history.png'><br>
# SVR_beststudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVR_beststudy_metrics.png'><br>
# SVR_beststudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVR_beststudy_score.png'><br>
# SVR_beststudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVR_beststudy_time.png'><br>
# SVR_overstudy_history.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVR_overstudy_history.png'><br>
# SVR_overstudy_metrics.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVR_overstudy_metrics.png'><br>
# SVR_overstudy_score.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVR_overstudy_score.png'><br>
# SVR_overstudy_time.png
# <br><img src='https://raw.githubusercontent.com/maskot1977/tmd2022/e8762fc2916d3f66d9bf605f4a871a9176f856a1/SVR_overstudy_time.png'><br>
